# %%
import numpy as np
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
military_data = pd.read_csv(pwd + '/military_expenditure.csv')
military_data
# Out:
#            country iso3c iso2c  year  Military expenditure (current USD)  \
# 0      Afghanistan   AFG    AF  1970                        2.939586e+06
# 1      Afghanistan   AFG    AF  1971                                 NaN
# 2      Afghanistan   AFG    AF  1972                                 NaN
# 3      Afghanistan   AFG    AF  1973                        3.341272e+06
# 4      Afghanistan   AFG    AF  1974                        3.581366e+06
# ...            ...   ...   ...   ...                                 ...
# 13561     Zimbabwe   ZWE    ZW  2016                        3.580650e+08
# 13562     Zimbabwe   ZWE    ZW  2017                        3.405220e+08
# 13563     Zimbabwe   ZWE    ZW  2018                        4.203640e+08
# 13564     Zimbabwe   ZWE    ZW  2019                        5.469390e+08
# 13565     Zimbabwe   ZWE    ZW  2020                                 NaN
#
#        Military expenditure (% of general government expenditure)  \
# ...

# %%
military_data.columns
# Out:
# Index(['country', 'iso3c', 'iso2c', 'year',
#        'Military expenditure (current USD)',
#        'Military expenditure (% of general government expenditure)',
#        'Military expenditure (% of GDP)', 'adminregion', 'incomeLevel'],
#       dtype='object')

# %%
updated_data = military_data.drop(columns=['iso3c','iso2c'])
updated_data
# Out:
#            country  year  Military expenditure (current USD)  \
# 0      Afghanistan  1970                        2.939586e+06
# 1      Afghanistan  1971                                 NaN
# 2      Afghanistan  1972                                 NaN
# 3      Afghanistan  1973                        3.341272e+06
# 4      Afghanistan  1974                        3.581366e+06
# ...            ...   ...                                 ...
# 13561     Zimbabwe  2016                        3.580650e+08
# 13562     Zimbabwe  2017                        3.405220e+08
# 13563     Zimbabwe  2018                        4.203640e+08
# 13564     Zimbabwe  2019                        5.469390e+08
# 13565     Zimbabwe  2020                                 NaN
#
#        Military expenditure (% of general government expenditure)  \
# 0                                                    NaN
# 1                                                    NaN
# ...

# %% [markdown]
# ## Begin by gathering summary statistical data for countries (avg expenditures etc...)

# %%
recent_afghani_data = updated_data[(updated_data['country'] == 'Afghanistan') & (updated_data['year'] >= 2004)]
recent_afghani_data.describe()
# Out:
#               year  Military expenditure (current USD)  \
# count    17.000000                        1.700000e+01
# mean   2012.000000                        2.187892e+08
# std       5.049752                        5.819388e+07
# min    2004.000000                        1.227272e+08
# 25%    2008.000000                        1.914071e+08
# 50%    2012.000000                        2.195802e+08
# 75%    2016.000000                        2.518695e+08
# max    2020.000000                        3.258070e+08
#
#        Military expenditure (% of general government expenditure)  \
# count                                          17.000000
# mean                                            7.505306
# std                                             3.975176
# min                                             3.652592
# 25%                                             4.275736
# 50%                                             5.109793
# ...

# %%
updated_data
# Out:
#            country  year  Military expenditure (current USD)  \
# 0      Afghanistan  1970                        2.939586e+06
# 1      Afghanistan  1971                                 NaN
# 2      Afghanistan  1972                                 NaN
# 3      Afghanistan  1973                        3.341272e+06
# 4      Afghanistan  1974                        3.581366e+06
# ...            ...   ...                                 ...
# 13561     Zimbabwe  2016                        3.580650e+08
# 13562     Zimbabwe  2017                        3.405220e+08
# 13563     Zimbabwe  2018                        4.203640e+08
# 13564     Zimbabwe  2019                        5.469390e+08
# 13565     Zimbabwe  2020                                 NaN
#
#        Military expenditure (% of general government expenditure)  \
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
updated_data[updated_data['incomeLevel'] == 'Low income']
# Out:
#            country  year  Military expenditure (current USD)  \
# 0      Afghanistan  1970                        2.939586e+06
# 1      Afghanistan  1971                                 NaN
# 2      Afghanistan  1972                                 NaN
# 3      Afghanistan  1973                        3.341272e+06
# 4      Afghanistan  1974                        3.581366e+06
# ...            ...   ...                                 ...
# 13459  Yemen, Rep.  2016                                 NaN
# 13460  Yemen, Rep.  2017                                 NaN
# 13461  Yemen, Rep.  2018                                 NaN
# 13462  Yemen, Rep.  2019                                 NaN
# 13463  Yemen, Rep.  2020                                 NaN
#
#        Military expenditure (% of general government expenditure)  \
# 0                                                    NaN
# 1                                                    NaN
# ...

# %% [markdown]
# ## Individual country spending in 2020

# %%
updated_data[updated_data['year'] == 2020]
# Out:
#                            country  year  Military expenditure (current USD)  \
# 50                     Afghanistan  2020                        2.795770e+08
# 101    Africa Eastern and Southern  2020                        1.057666e+10
# 152     Africa Western and Central  2020                        7.038811e+09
# 203                        Albania  2020                        2.220227e+08
# 254                        Algeria  2020                        9.708277e+09
# ...                            ...   ...                                 ...
# 13361           West Bank and Gaza  2020                                 NaN
# 13412                        World  2020                        1.928852e+12
# 13463                  Yemen, Rep.  2020                                 NaN
# 13514                       Zambia  2020                        2.121424e+08
# 13565                     Zimbabwe  2020                                 NaN
#
# ...

# %% [markdown]
# # Movie Stuff and Info

# %%
netflix_info = pd.read_csv(pwd + '/netflix_titles.csv')
netflix_info
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix_info[(netflix_info['country'] == 'United States') & (netflix_info['cast'].str.split(','))]
# Out:
#      show_id   type                       title         director  \
# 3         s4  Movie                           9      Shane Acker
# 4         s5  Movie                          21   Robert Luketic
# 7         s8  Movie                         187   Kevin Reynolds
# 10       s11  Movie                        1922     Zak Hilditch
# 14       s15  Movie                        3022       John Suits
# ...      ...    ...                         ...              ...
# 7758   s7759  Movie  Zack and Miri Make a Porno      Kevin Smith
# 7771   s7772  Movie                        Zion       Floyd Russ
# 7774   s7775  Movie                      Zodiac    David Fincher
# 7778   s7779  Movie                  Zombieland  Ruben Fleischer
# 7781   s7782  Movie                        Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...
